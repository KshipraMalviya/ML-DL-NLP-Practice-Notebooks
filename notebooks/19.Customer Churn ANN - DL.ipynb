# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df=pd.read_csv("D:/DataML/churn.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df=df.drop(['CustomerId','Surname'],axis='columns')
df
# Out:
#       RowNumber  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0             1          619    France  Female   42       2       0.00
# 1             2          608     Spain  Female   41       1   83807.86
# 2             3          502    France  Female   42       8  159660.80
# 3             4          699    France  Female   39       1       0.00
# 4             5          850     Spain  Female   43       2  125510.82
# ...         ...          ...       ...     ...  ...     ...        ...
# 9995       9996          771    France    Male   39       5       0.00
# 9996       9997          516    France    Male   35      10   57369.61
# 9997       9998          709    France  Female   36       7       0.00
# 9998       9999          772   Germany    Male   42       3   75075.31
# 9999      10000          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# 1                 1          0               1        112542.58       0
# 2                 3          1               0        113931.57       1
# 3                 2          0               0         93826.63       0
# 4                 1          1               1         79084.10       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
# [10000 rows x 12 columns]

# %%
df=df.drop('RowNumber',axis='columns')

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df['Gender'].replace({'Female':1,'Male':0},inplace=True)
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       1   42       2       0.00              1
# 1             608     Spain       1   41       1   83807.86              1
# 2             502    France       1   42       8  159660.80              3
# 3             699    France       1   39       1       0.00              2
# 4             850     Spain       1   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       0   39       5       0.00              2
# 9996          516    France       0   35      10   57369.61              1
# 9997          709    France       1   36       7       0.00              1
# 9998          772   Germany       0   42       3   75075.31              2
# 9999          792    France       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
dummies=pd.get_dummies(df['Geography']).astype(int)

# %%
df=pd.concat([df,dummies],axis='columns')
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       1   42       2       0.00              1
# 1             608     Spain       1   41       1   83807.86              1
# 2             502    France       1   42       8  159660.80              3
# 3             699    France       1   39       1       0.00              2
# 4             850     Spain       1   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       0   39       5       0.00              2
# 9996          516    France       0   35      10   57369.61              1
# 9997          709    France       1   36       7       0.00              1
# 9998          772   Germany       0   42       3   75075.31              2
# 9999          792    France       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  France  Germany  \
# 0             1               1        101348.88       1       1        0
# 1             0               1        112542.58       0       0        0
# 2             1               0        113931.57       1       1        0
# 3             0               0         93826.63       0       1        0
# 4             1               1         79084.10       0       0        0
# ...         ...             ...              ...     ...     ...      ...
# 9995          1               0         96270.64       0       1        0
# 9996          1               1        101699.77       0       1        0
# 9997          0               1         42085.58       1       1        0
# 9998          1               0         92888.52       1       0        1
# 9999          1               0         38190.78       0       1        0
#
#       Spain
# 0         0
# 1         1
# 2         0
# 3         0
# 4         1
# ...     ...
# 9995      0
# 9996      0
# 9997      0
# 9998      0
# 9999      0
#
# [10000 rows x 14 columns]

# %%
df.drop('Geography',axis='columns', inplace=True)
df
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       1   42       2       0.00              1          1
# 1             608       1   41       1   83807.86              1          0
# 2             502       1   42       8  159660.80              3          1
# 3             699       1   39       1       0.00              2          0
# 4             850       1   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       0   39       5       0.00              2          1
# 9996          516       0   35      10   57369.61              1          1
# 9997          709       1   36       7       0.00              1          0
# 9998          772       0   42       3   75075.31              2          1
# 9999          792       1   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  France  Germany  Spain
# 0                  1        101348.88       1       1        0      0
# 1                  1        112542.58       0       0        0      1
# 2                  0        113931.57       1       1        0      0
# 3                  0         93826.63       0       1        0      0
# 4                  1         79084.10       0       0        0      1
# ...              ...              ...     ...     ...      ...    ...
# 9995               0         96270.64       0       1        0      0
# 9996               1        101699.77       0       1        0      0
# 9997               1         42085.58       1       1        0      0
# 9998               0         92888.52       1       0        1      0
# 9999               0         38190.78       0       1        0      0
#
# [10000 rows x 13 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
cols_to_scale=['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']

# %%
scaler=MinMaxScaler()
df[cols_to_scale]=scaler.fit_transform(df[cols_to_scale])
df
# Out:
#       CreditScore  Gender       Age  Tenure   Balance  NumOfProducts  \
# 0           0.538       1  0.324324     0.2  0.000000       0.000000
# 1           0.516       1  0.310811     0.1  0.334031       0.000000
# 2           0.304       1  0.324324     0.8  0.636357       0.666667
# 3           0.698       1  0.283784     0.1  0.000000       0.333333
# 4           1.000       1  0.337838     0.2  0.500246       0.000000
# ...           ...     ...       ...     ...       ...            ...
# 9995        0.842       0  0.283784     0.5  0.000000       0.333333
# 9996        0.332       0  0.229730     1.0  0.228657       0.000000
# 9997        0.718       1  0.243243     0.7  0.000000       0.000000
# 9998        0.844       0  0.324324     0.3  0.299226       0.333333
# 9999        0.884       1  0.135135     0.4  0.518708       0.000000
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  France  Germany  \
# 0             1               1         0.506735       1       1        0
# 1             0               1         0.562709       0       0        0
# 2             1               0         0.569654       1       1        0
# 3             0               0         0.469120       0       1        0
# 4             1               1         0.395400       0       0        0
# ...         ...             ...              ...     ...     ...      ...
# 9995          1               0         0.481341       0       1        0
# 9996          1               1         0.508490       0       1        0
# 9997          0               1         0.210390       1       1        0
# 9998          1               0         0.464429       1       0        1
# 9999          1               0         0.190914       0       1        0
#
#       Spain
# 0         0
# 1         1
# 2         0
# 3         0
# 4         1
# ...     ...
# 9995      0
# 9996      0
# 9997      0
# 9998      0
# 9999      0
#
# [10000 rows x 13 columns]

# %%
df.dtypes
# Out:
# CreditScore        float64
# Gender               int64
# Age                float64
# Tenure             float64
# Balance            float64
# NumOfProducts      float64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# France               int32
# Germany              int32
# Spain                int32
# dtype: object

# %%
X=df.drop('Exited',axis='columns')
y=df['Exited']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=18)

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
model=keras.Sequential([
    keras.layers.Dense(12,input_shape=(12,), activation='relu'),
    keras.layers.Dense(8,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 3s 4ms/step - loss: 0.5495 - accuracy: 0.7606
# Epoch 2/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4661 - accuracy: 0.7995
# Epoch 3/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4541 - accuracy: 0.7995
# Epoch 4/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4459 - accuracy: 0.7995
# Epoch 5/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4394 - accuracy: 0.7995
# Epoch 6/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4326 - accuracy: 0.7995
# Epoch 7/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4279 - accuracy: 0.7996
# Epoch 8/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4229 - accuracy: 0.8180
# Epoch 9/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4191 - accuracy: 0.8190
# Epoch 10/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4136 - accuracy: 0.8213

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 [==============================] - 1s 5ms/step - loss: 0.4283 - accuracy: 0.8200
# [0.4283134341239929, 0.8199999928474426]
