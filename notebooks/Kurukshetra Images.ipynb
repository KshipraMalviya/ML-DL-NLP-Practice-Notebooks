# %%
import numpy as np
import pandas as pd

# %%
images = pd.read_csv("D:/DataML/images.csv")

# %%
images
# Out:
#                                        Destination  \
# 0                                   Brahma Sarovar
# 1                                         Jyotisar
# 2                               Sri Krishna Museum
# 3                        Panorama & Science Centre
# 4            Mini Zoo & Black Buck Breeding Centre
# 5                            Shri Vyas Gaudiyamath
# 6                                        Ban Ganga
# 7                                   OP Jindal Park
# 8   Shri Venkateswara Swamy Tirupati Balaji Temple
# 9        Shri Dakshin Mukhi Prachin Hanuman Mandir
# 10                                  Buddhist Stupa
# 11                                  Faridkot House
# 12              Shri Aadinath Digambar Jain Mandir
# 13                          Lakshmi Narayan Mandir
# 14                                 1857 War Museum
# 15                   Bhadrakali Shaktipeeth Temple
# 16                                        Dharohar
# ...

# %%
import pickle

# %%
with open('images.pkl', 'wb') as f:
    pickle.dump(images, f)
